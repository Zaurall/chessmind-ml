# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %%
import tensorflow as tf
import pandas as pd
import os
from sklearn.model_selection import train_test_split


image_size = (224, 224)  
batch_size = 32          

csv_file = "../data/cells/dataset.csv"  
image_dir = "../data/cells/"      

df = pd.read_csv(csv_file)


df['image_path'] = df['Filename'].apply(lambda x: os.path.join(image_dir, x))

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

df
# Out:
#            Site  Figure  Color                                   Filename  \
# 0    chessarena  bishop  black       chessarena_black_bishop_on_black.png
# 1    chessarena  bishop  black       chessarena_black_bishop_on_white.png
# 2    chessarena  bishop  black       chessarena_black_bishop_selected.png
# 3    chessarena    king  black            chessarena_black_king_check.png
# 4    chessarena    king  black        chessarena_black_king_checkmate.png
# ..          ...     ...    ...                                        ...
# 169     lichess   queen  white  lichess_white_queen_on_white_selected.png
# 170     lichess    rook  white            lichess_white_rook_on_black.png
# 171     lichess    rook  white   lichess_white_rook_on_black_selected.png
# 172     lichess    rook  white            lichess_white_rook_on_white.png
# 173     lichess    rook  white   lichess_white_rook_on_white_selected.png
#
#                                             image_path
# 0    ../data/cells/chessarena_black_bishop_on_black...
# 1    ../data/cells/chessarena_black_bishop_on_white...
# 2    ../data/cells/chessarena_black_bishop_selected...
# 3        ../data/cells/chessarena_black_king_check.png
# 4    ../data/cells/chessarena_black_king_checkmate.png
# ..                                                 ...
# 169  ../data/cells/lichess_white_queen_on_white_sel...
# 170      ../data/cells/lichess_white_rook_on_black.png
# 171  ../data/cells/lichess_white_rook_on_black_sele...
# 172      ../data/cells/lichess_white_rook_on_white.png
# 173  ../data/cells/lichess_white_rook_on_white_sele...
#
# [174 rows x 5 columns]

# %%
def preprocess_image(file_path, label_figure, label_color):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, image_size)
    img = img / 255.0  

    return img, (label_figure, label_color)


def create_dataset(dataframe):
    file_paths = dataframe['image_path'].values
    figure_labels = dataframe['Figure'].map(figure_to_label).values
    color_labels = dataframe['Color'].map(color_to_label).values
    
    dataset = tf.data.Dataset.from_tensor_slices((file_paths, figure_labels, color_labels))
    dataset = dataset.map(lambda x, y, z: preprocess_image(x, y, z), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch_size).prefetch(buffer_size=tf.data.AUTOTUNE)
    
    return dataset

# %%
figure_to_label = {figure: idx for idx, figure in enumerate(df['Figure'].unique())}
color_to_label = {color: idx for idx, color in enumerate(df['Color'].unique())}

train_dataset = create_dataset(train_df)
test_dataset = create_dataset(test_df)

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall

def create_custom_model(input_shape, num_figures, num_colors):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(32, (3, 3), activation='relu')(inputs)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(128, (3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(128, (3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)

    figure_output = layers.Dense(num_figures, activation='softmax', name='figure')(x)
    color_output = layers.Dense(num_colors, activation='softmax', name='color')(x)
    model = models.Model(inputs=inputs, outputs=[figure_output, color_output])
    return model

input_shape = (224, 224, 3)  
num_figures = len(figure_to_label) 
num_colors = len(color_to_label)

# %%
    
model = create_custom_model(input_shape, num_figures, num_colors)

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss={
        'figure': 'sparse_categorical_crossentropy', 
        'color': 'sparse_categorical_crossentropy'
    },
    metrics={
        'figure': ['accuracy'],  
        'color': ['accuracy'],
    }
)

model.summary()

history = model.fit(train_dataset, epochs=15, validation_data=test_dataset)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 222, 222,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 111, 111,  │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 109, 109,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 54, 54,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 52, 52,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 26, 26,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 24, 24,    │    147,584 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 12, 12,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 18432)     │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │  4,718,848 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ figure (Dense)      │ (None, 8)         │      2,056 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ color (Dense)       │ (None, 4)         │      1,028 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,962,764 (18.93 MB)
#  Trainable params: 4,962,764 (18.93 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - color_accuracy: 0.3772 - color_loss: 1.3488 - figure_accuracy: 0.1574 - figure_loss: 2.2325 - loss: 3.5899 - val_color_accuracy: 0.3714 - val_color_loss: 0.9982 - val_figure_accuracy: 0.1143 - val_figure_loss: 2.1143 - val_loss: 3.0549
# Epoch 2/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - color_accuracy: 0.5125 - color_loss: 1.1385 - figure_accuracy: 0.1608 - figure_loss: 2.0508 - loss: 3.1974 - val_color_accuracy: 0.9143 - val_color_loss: 0.6920 - val_figure_accuracy: 0.2286 - val_figure_loss: 2.1395 - val_loss: 2.7188
# Epoch 3/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step - color_accuracy: 0.6610 - color_loss: 1.0164 - figure_accuracy: 0.2141 - figure_loss: 1.9827 - loss: 3.0090 - val_color_accuracy: 0.9714 - val_color_loss: 0.5140 - val_figure_accuracy: 0.3429 - val_figure_loss: 1.8991 - val_loss: 2.2797
# Epoch 4/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - color_accuracy: 0.7323 - color_loss: 0.7668 - figure_accuracy: 0.3376 - figure_loss: 1.7558 - loss: 2.5338 - val_color_accuracy: 0.9429 - val_color_loss: 0.3053 - val_figure_accuracy: 0.6000 - val_figure_loss: 1.3405 - val_loss: 1.4885
# Epoch 5/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - color_accuracy: 0.8157 - color_loss: 0.5315 - figure_accuracy: 0.5745 - figure_loss: 1.3108 - loss: 1.8348 - val_color_accuracy: 0.9714 - val_color_loss: 0.2155 - val_figure_accuracy: 0.8286 - val_figure_loss: 1.0077 - val_loss: 1.1253
# Epoch 6/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step - color_accuracy: 0.8703 - color_loss: 0.4277 - figure_accuracy: 0.7314 - figure_loss: 0.9735 - loss: 1.3974 - val_color_accuracy: 0.9714 - val_color_loss: 0.1398 - val_figure_accuracy: 0.8571 - val_figure_loss: 0.5495 - val_loss: 0.7062
# Epoch 7/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - color_accuracy: 0.8490 - color_loss: 0.4487 - figure_accuracy: 0.7720 - figure_loss: 0.6899 - loss: 1.1437 - val_color_accuracy: 0.9714 - val_color_loss: 0.1927 - val_figure_accuracy: 0.9429 - val_figure_loss: 0.2679 - val_loss: 0.5689
# Epoch 8/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - color_accuracy: 0.8116 - color_loss: 0.4162 - figure_accuracy: 0.7990 - figure_loss: 0.6407 - loss: 1.0572 - val_color_accuracy: 0.9714 - val_color_loss: 0.1484 - val_figure_accuracy: 0.9143 - val_figure_loss: 0.2081 - val_loss: 0.5466
# Epoch 9/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - color_accuracy: 0.8838 - color_loss: 0.3694 - figure_accuracy: 0.8170 - figure_loss: 0.5767 - loss: 0.9602 - val_color_accuracy: 0.9714 - val_color_loss: 0.1752 - val_figure_accuracy: 0.9714 - val_figure_loss: 0.1382 - val_loss: 0.5121
# Epoch 10/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - color_accuracy: 0.8824 - color_loss: 0.3351 - figure_accuracy: 0.8236 - figure_loss: 0.5814 - loss: 0.9204 - val_color_accuracy: 0.9714 - val_color_loss: 0.2018 - val_figure_accuracy: 0.9429 - val_figure_loss: 0.3002 - val_loss: 0.4710
# Epoch 11/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - color_accuracy: 0.8898 - color_loss: 0.2979 - figure_accuracy: 0.8366 - figure_loss: 0.4105 - loss: 0.7039 - val_color_accuracy: 0.9429 - val_color_loss: 0.3029 - val_figure_accuracy: 0.9429 - val_figure_loss: 0.2450 - val_loss: 0.4184
# Epoch 12/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - color_accuracy: 0.9431 - color_loss: 0.1490 - figure_accuracy: 0.8496 - figure_loss: 0.3384 - loss: 0.4910 - val_color_accuracy: 0.9429 - val_color_loss: 0.3156 - val_figure_accuracy: 0.9429 - val_figure_loss: 0.1276 - val_loss: 0.2830
# Epoch 13/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - color_accuracy: 0.9372 - color_loss: 0.1817 - figure_accuracy: 0.8687 - figure_loss: 0.3675 - loss: 0.5396 - val_color_accuracy: 0.9143 - val_color_loss: 0.4238 - val_figure_accuracy: 0.9429 - val_figure_loss: 0.3141 - val_loss: 0.4282
# Epoch 14/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - color_accuracy: 0.9296 - color_loss: 0.1971 - figure_accuracy: 0.9020 - figure_loss: 0.3438 - loss: 0.5553 - val_color_accuracy: 0.9429 - val_color_loss: 0.2678 - val_figure_accuracy: 0.9429 - val_figure_loss: 0.2497 - val_loss: 0.3351
# Epoch 15/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step - color_accuracy: 0.8694 - color_loss: 0.3513 - figure_accuracy: 0.9083 - figure_loss: 0.2965 - loss: 0.6506 - val_color_accuracy: 0.9143 - val_color_loss: 0.3067 - val_figure_accuracy: 0.9429 - val_figure_loss: 0.4666 - val_loss: 0.4079

# %%
model.save('../models/model_figures.h5')

# %%
train_color_loss = history.history['color_loss']
val_color_loss = history.history['val_color_loss']

train_color_accuracy= history.history['color_accuracy']
val_color_accuracy= history.history['val_color_accuracy']


train_figure_loss= history.history['figure_loss']
val_figure_loss= history.history['val_figure_loss']

train_figure_accuracy= history.history['figure_accuracy']
val_figure_accuracy= history.history['val_figure_accuracy']

# %%
import matplotlib.pyplot as plt

# Данные
train_color_loss = history.history['color_loss']
val_color_loss = history.history['val_color_loss']
train_color_accuracy = history.history['color_accuracy']
val_color_accuracy = history.history['val_color_accuracy']

train_figure_loss = history.history['figure_loss']
val_figure_loss = history.history['val_figure_loss']
train_figure_accuracy = history.history['figure_accuracy']
val_figure_accuracy = history.history['val_figure_accuracy']

epochs = range(1, len(train_color_loss) + 1)

plt.figure(figsize=(14, 10))

plt.subplot(2, 2, 1)
plt.plot(epochs, train_color_loss, 'bo-', label='Train Color Loss')
plt.plot(epochs, val_color_loss, 'ro-', label='Val Color Loss')
plt.title('Color Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(epochs, train_figure_loss, 'bo-', label='Train Figure Loss')
plt.plot(epochs, val_figure_loss, 'ro-', label='Val Figure Loss')
plt.title('Figure Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(epochs, train_color_accuracy, 'bo-', label='Train Color Accuracy')
plt.plot(epochs, val_color_accuracy, 'ro-', label='Val Color Accuracy')
plt.title('Color Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(epochs, train_figure_accuracy, 'bo-', label='Train Figure Accuracy')
plt.plot(epochs, val_figure_accuracy, 'ro-', label='Val Figure Accuracy')
plt.title('Figure Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
